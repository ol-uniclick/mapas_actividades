# %% [markdown]
# # Mapas Python 2

# %%
import sys
sys.path.append('./')
from mapas import *

# %% [markdown]
# Podemos cargar el mapa generado con elnotebook anteior indicandole que el delimitador es "|".

# %%
mapa = Mapa('mapa_demo_2.txt', delimiter='|')

# %% [markdown]
# Para desplegar la tabla fuera del notebook usamos la función `view` sobre el dataframe del mapa.

# %%
view(mapa.df)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840)); win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>LINEA</th>\      <th>OBJETIVO</th>\      <th>ACTIVIDAD_PRIMARIA</th>\      <th>ACTIVIDAD_SECUNDARIA</th>\      <th>ACTIVIDAD_PUNTUAL</th>\      <th>SEMANA_INICIO</th>\      <th>SEMANA_FIN</th>\      <th>ESTATUS_PUNTUAL</th>\      <th>IMPORTANCIA_PUNTUAL</th>\      <th>IMPORTANCIA_SECUNDARIA</th>\      <th>IMPORTANCIA_PRIMARIA</th>\      <th>IMPORTANCIA_OBJETIVO</th>\      <th>IMPORTANCIA_LINEA</th>\      <th>ID_OBJETIVO</th>\      <th>ID_PRIMARIA</th>\      <th>ID_SECUNDARIA</th>\      <th>ID_PUNTUAL</th>\      <th>SEMANA</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>0</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>CONEXION AL SAT</td>\      <td>CONEXION SAT</td>\      <td>1</td>\      <td>2</td>\      <td>TERMINADO</td>\      <td>D</td>\      <td>C</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>00</td>\      <td>00</td>\      <td>9</td>\    </tr>\    <tr>\      <th>1</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>CONEXION AL SAT</td>\      <td>EXTRACCION CAPTCHAS</td>\      <td>2</td>\      <td>2</td>\      <td>TERMINADO</td>\      <td>D</td>\      <td>C</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>00</td>\      <td>01</td>\      <td>9</td>\    </tr>\    <tr>\      <th>2</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>CONEXION AL SAT</td>\      <td>GENERACION DE DATOS PARA ENTRENAMIENTO</td>\      <td>2</td>\      <td>2</td>\      <td>TERMINADO</td>\      <td>D</td>\      <td>C</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>00</td>\      <td>02</td>\      <td>9</td>\    </tr>\    <tr>\      <th>3</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>CONSTANCIA SITUACION FISCAL</td>\      <td>EXPLORACION Y DEFINICION DE MODELOS DE DATOS SAT</td>\      <td>4</td>\      <td>5</td>\      <td>TERMINADO</td>\      <td>D</td>\      <td>B</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>01</td>\      <td>00</td>\      <td>9</td>\    </tr>\    <tr>\      <th>4</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>CONSTANCIA SITUACION FISCAL</td>\      <td>OBTENCION CONSTANCIA DE SITUACION FISCAL</td>\      <td>4</td>\      <td>4</td>\      <td>TERMINADO</td>\      <td>C</td>\      <td>B</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>01</td>\      <td>01</td>\      <td>9</td>\    </tr>\    <tr>\      <th>5</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>FACTURACION</td>\      <td>EXPLORACION PAGINA FACTURACION</td>\      <td>5</td>\      <td>5</td>\      <td>TERMINADO</td>\      <td>C</td>\      <td>D</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>02</td>\      <td>00</td>\      <td>9</td>\    </tr>\    <tr>\      <th>6</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      <td>SCRAPER SAT</td>\      <td>FACTURACION</td>\      <td>SCRAPER FACTURACION</td>\      <td>5</td>\      <td>6</td>\      <td>TERMINADO</td>\      <td>D</td>\      <td>D</td>\      <td>D</td>\      <td>D</td>\      <td>E</td>\      <td>00</td>\      <td>00</td>\      <td>02</td>\      <td>01</td>\      <td>9</td>\    </tr>\    <tr>\      <th>7</th>\      <td>ROBINA</td>\      <td>SERVICIO SAT</td>\      ...

# %% [markdown]
# Para filtrar la tabla y unicamente ver el status deseados se usa el método `status`. Usando como argumento l status que deseamos visualizar: TERMINADO/PENDIENTE/RECURRENTE/EN PROCESO

# %%
mapa.status('TERMINADO')
# Out:
#      LINEA      OBJETIVO ACTIVIDAD_PRIMARIA         ACTIVIDAD_SECUNDARIA  \
# 0   ROBINA  SERVICIO SAT        SCRAPER SAT              CONEXION AL SAT
# 1   ROBINA  SERVICIO SAT        SCRAPER SAT              CONEXION AL SAT
# 2   ROBINA  SERVICIO SAT        SCRAPER SAT              CONEXION AL SAT
# 3   ROBINA  SERVICIO SAT        SCRAPER SAT  CONSTANCIA SITUACION FISCAL
# 4   ROBINA  SERVICIO SAT        SCRAPER SAT  CONSTANCIA SITUACION FISCAL
# 5   ROBINA  SERVICIO SAT        SCRAPER SAT                  FACTURACION
# 6   ROBINA  SERVICIO SAT        SCRAPER SAT                  FACTURACION
# 7   ROBINA  SERVICIO SAT        SCRAPER SAT                DECLARACIONES
# 9   ROBINA  SERVICIO SAT        SCRAPER SAT            DESCARGAS MASIVAS
# 10  ROBINA  SERVICIO SAT        SCRAPER SAT            DESCARGAS MASIVAS
# 13  ROBINA  SERVICIO SAT        SCRAPER SAT                  IA CAPTCHAS
# 14  ROBINA  SERVICIO SAT        SCRAPER SAT                  IA CAPTCHAS
# 15  ROBINA  SERVICIO SAT        SCRAPER SAT                  IA CAPTCHAS
# 17  ROBINA  SERVICIO SAT        SCRAPER SAT                  IA CAPTCHAS
# 18  ROBINA  SERVICIO SAT        SCRAPER SAT            SERVICIO CAPTCHAS
# 19  ROBINA  SERVICIO SAT        SCRAPER SAT            SERVICIO CAPTCHAS
#
#                                    ACTIVIDAD_PUNTUAL SEMANA_INICIO SEMANA_FIN  \
# 0                                       CONEXION SAT             1          2
# 1                                EXTRACCION CAPTCHAS             2          2
# 2             GENERACION DE DATOS PARA ENTRENAMIENTO             2          2
# 3   EXPLORACION Y DEFINICION DE MODELOS DE DATOS SAT             4          5
# 4           OBTENCION CONSTANCIA DE SITUACION FISCAL             4          4
# 5                     EXPLORACION PAGINA FACTURACION             5          5
# 6                                SCRAPER FACTURACION             5          6
# 7                   EXPLORACION PAGINA DECLARACIONES             7          7
# 9                                    AGREGAR PROXIES             8          8
# 10                         GENERADOR MULTIPROCESSING             8          8
# 13                           SELECCION DEL MODELO IA             2          2
# 14            DESARROLLO E IMPLEMENTACION DEL MODELO             2          3
# 15                          ENTRENAMIENTO DEL MODELO             3          3
# 17                 PRUEBAS Y CARACTERIZACION CAPTCHA             3          3
# 18             SERVIDOR LOCAL PARA RESOLVER CAPTCHAS             4          4
# 19       INTEGRAR SERVIDOR DE CAPTCHAS A SCRAPER SAT             4          4
#
#    ESTATUS_PUNTUAL IMPORTANCIA_PUNTUAL IMPORTANCIA_SECUNDARIA  \
# 0        TERMINADO                   D                      C
# 1        TERMINADO                   D                      C
# 2        TERMINADO                   D                      C
# 3        TERMINADO                   D                      B
# 4        TERMINADO                   C                      B
# 5        TERMINADO                   C                      D
# 6        TERMINADO                   D                      D
# 7        TERMINADO                   C                      C
# 9        TERMINADO                   C                      D
# 10       TERMINADO                   D                      D
# 13       TERMINADO                   D                      C
# 14       TERMINADO                   D                      C
# 15       TERMINADO                   D                      C
# 17       TERMINADO                   C                      C
# 18       TERMINADO                   C                      C
# 19       TERMINADO                   C                      C
#
#    IMPORTANCIA_PRIMARIA IMPORTANCIA_OBJETIVO IMPORTANCIA_LINEA ID_OBJETIVO  \
# 0                     D                    D                 E          00
# 1                     D                    D                 E          00
# 2                     D                    D                 E          00
# 3                     D                    D                 E          00
# 4                     D                    D                 E          00
# 5                     D                    D                 E          00
# 6                     D                    D                 E          00
# 7                     D                    D                 E          00
# 9                     D                    D                 E          00
# 10                    D                    D                 E          00
# 13                    D                    D                 E          00
# 14                    D                    D                 E          00
# 15                    D                    D                 E          00
# 17                    D                    D                 E          00
# 18                    D                    D                 E          00
# 19                    D                    D                 E          00
#
#    ID_PRIMARIA ID_SECUNDARIA ID_PUNTUAL  SEMANA
# 0           00            00         00       9
# 1           00            00         01       9
# 2           00            00         02       9
# 3           00            01         00       9
# 4           00            01         01       9
# 5           00            02         00       9
# 6           00            02         01       9
# 7           00            03         00       9
# 9           00            04         00       9
# 10          00            04         01       9
# 13          00            05         00       9
# 14          00            05         01       9
# 15          00            05         02       9
# 17          00            05         04       9
# 18          00            06         00       9
# 19          00            06         01       9

# %%
mapa.status('PENDIENTE')
# Out:
#      LINEA      OBJETIVO ACTIVIDAD_PRIMARIA ACTIVIDAD_SECUNDARIA  \
# 20  ROBINA  SERVICIO SAT        SCRAPER SAT    SERVICIO CAPTCHAS
# 21  ROBINA  SERVICIO SAT        SCRAPER SAT    SERVICIO CAPTCHAS
# 22  ROBINA  SERVICIO SAT        SCRAPER SAT          INTEGRACION
# 23  ROBINA  SERVICIO SAT        SCRAPER SAT          INTEGRACION
# 24  ROBINA  SERVICIO SAT        SCRAPER SAT              PRUEBAS
# 25  ROBINA  SERVICIO SAT        SCRAPER SAT              PRUEBAS
#
#                               ACTIVIDAD_PUNTUAL SEMANA_INICIO SEMANA_FIN  \
# 20  IMPLEMENTACION DE WEBSERVICE CAPTCHA (NUBE)            10         10
# 21        INTEGRAR WEBSERVICE CAPTCHA A SCRAPER            10         10
# 22                   CONEXION CON BASE DE DATOS            11         11
# 23                    DESARROLLO WEBSERVICE SAT            12         12
# 24                                 PRUEBAS Y QA            11         12
# 25                          PUESTA A PRODUCCION            13         13
#
#    ESTATUS_PUNTUAL IMPORTANCIA_PUNTUAL IMPORTANCIA_SECUNDARIA  \
# 20       PENDIENTE                   C                      C
# 21       PENDIENTE                   C                      C
# 22       PENDIENTE                   C                      C
# 23       PENDIENTE                   D                      C
# 24       PENDIENTE                   D                      C
# 25       PENDIENTE                   D                      C
#
#    IMPORTANCIA_PRIMARIA IMPORTANCIA_OBJETIVO IMPORTANCIA_LINEA ID_OBJETIVO  \
# 20                    D                    D                 E          00
# 21                    D                    D                 E          00
# 22                    D                    D                 E          00
# 23                    D                    D                 E          00
# 24                    D                    D                 E          00
# 25                    D                    D                 E          00
#
#    ID_PRIMARIA ID_SECUNDARIA ID_PUNTUAL  SEMANA
# 20          00            06         02       9
# 21          00            06         03       9
# 22          00            07         00       9
# 23          00            07         01       9
# 24          00            08         00       9
# 25          00            08         01       9

# %% [markdown]
# Para ver el resumen de las actividades se selecciona la función mapa_actividades y se le aplica al dataframe del mapa.
#
# En este ejemplo vamos a aplicarlo al dataframe de las actividades terminadas. Adem'as se pondra el argumento `fecha_fin+T`

# %%
terminadas = mapa.status('TERMINADO')
resumen_actividades(terminadas, fecha_fin=True)
# Out:
# ROBINA
#     SERVICIO SAT
#         SCRAPER SAT
#             CONEXION AL SAT
#                 CONEXION SAT, 08/01/2021
#                 EXTRACCION CAPTCHAS, 08/01/2021
#                 GENERACION DE DATOS PARA ENTRENAMIENTO, 08/01/2021
#             CONSTANCIA SITUACION FISCAL
#                 OBTENCION CONSTANCIA DE SITUACION FISCAL, 22/01/2021
#                 EXPLORACION Y DEFINICION DE MODELOS DE DATOS SAT, 29/01/2021
#             DECLARACIONES
#                 EXPLORACION PAGINA DECLARACIONES, 12/02/2021
#             DESCARGAS MASIVAS
#                 AGREGAR PROXIES, 19/02/2021
#                 GENERADOR MULTIPROCESSING, 19/02/2021
#             FACTURACION
#                 EXPLORACION PAGINA FACTURACION, 29/01/2021
#                 SCRAPER FACTURACION, 05/02/2021
#             IA CAPTCHAS
#                 SELECCION DEL MODELO IA, 08/01/2021
#                 DESARROLLO E IMPLEMENTACION DEL MODELO, 15/01/2021
#                 ENTRENAMIENTO DEL MODELO, 15/01/2021
#                 PRUEBAS Y CARACTERIZACION CAPTCHA, 15/01/2021
#             SERVICIO CAPTCHAS
#                 INTEGRAR SERVIDOR DE CAPTCHAS A SCRAPER SAT, 22/01/2021
#                 SERVIDOR LOCAL PARA RESOLVER CAPTCHAS, 22/01/2021
# /home/oscar/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py:68: PerformanceWarning: indexing past lexsort depth may impact performance.
#   coro.send(None)

# %% [markdown]
# ----
